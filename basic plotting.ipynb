# %%
import pandas
import pandas as pd

# %%
oo = pd.read_csv('olympics.csv', skiprows=4)
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
# import krdni matplotlib.pyplot bo bakarhenani chart
import matplotlib.pyplot as plt

# %%
# awanai salakanyan 1896'n ba pei sport'akanyan bom bzhmera
fo = oo[(oo.Edition == 1896)]
fo = fo.Sport.value_counts()
fo
# Out:
# Gymnastics       45
# Athletics        37
# Cycling          16
# Shooting         15
# Aquatics         11
# Tennis           10
# Fencing           8
# Weightlifting     6
# Wrestling         3
# Name: Sport, dtype: int64

# %%
fo.plot(kind='line');

# %%
fo.plot(kind='bar');

# %%
fo.plot(kind='barh');

# %%
fo.plot(kind='pie');

# %%
fo.plot(kind='bar', color='black');

# %%
fo.plot(kind='line', color='purple', figsize=(12, 4));

# %%
# !conda install -c anaconda seaborn

# %%
import seaborn as sns

# %%
sns.countplot(data=oo, x='Medal');

# %%
sns.countplot(data=oo, x='Medal', hue='Gender');

# %%
# awanai Edition'akanyan 2008'aw NOC'akanyan CHN'a
mw = oo[(oo.Edition == 2008) & (oo.NOC == 'CHN')]

# %%
mw.Gender.value_counts().plot(kind='bar');

# %%
# Gender'akanyanm bo bena
sns.countplot(data=oo, x='Gender');

# %%
sns.countplot(data=oo, x='Gender', palette='bwr');

# %%
sns.countplot(data=oo, x='Medal', hue='Gender');

# %%
sns.countplot(data=oo, x='Medal', hue='Gender', palette='bwr', order=['Silver', 'Gold', 'Bronze']);
